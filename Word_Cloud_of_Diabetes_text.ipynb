# %% [markdown]
# <a href="https://colab.research.google.com/github/IbrahimTGhanem/DiabetesPrediction/blob/main/Word_Cloud_of_Diabetes_text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1: Importing Libraries and exploring data**

# %%
# !pip install contractions
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.8/110.8 kB 11.1 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import contractions

# %%
# Import necessary libraries

# Upload Options
user_choice = input("Specify user (I):")

if user_choice == 'I':
    # Option I: Mount Google Drive - Ibrahim
    from google.colab import drive
    drive.mount('/content/drive')
    df = pd.read_csv("/content/drive/My Drive/Colab Notebooks/ML 2023/0 Datathons/Datathon 6/Diabetes.csv", encoding='ISO-8859-1')

else:
    print("Invalid choice. Please specify user (I) and try again.")

print(df.shape)
# Out:
# Specify user (I):I
# Mounted at /content/drive
# (50, 3)

# %%
import warnings
warnings.filterwarnings("ignore")

# Import the necessary libraries for data cleaning
import re  # Regular expressions library for text manipulation

# Display the first few rows (head) of the DataFrame to inspect the data
df.head()
# Out:
#                                            Citations  Year  \
# 0  Tasin, I., Nabil, T. U., Islam, S., & Khan, R....  2022
# 1  Abnoosian, K., Farnoosh, R., & Behzadi, M. H. ...  2023
# 2  Kibria, H. B., Nahiduzzaman, M., Goni, M. O. F...  2022
# 3  Ganie, S. M., Malik, M. B., & Arif, T. (2022)....  2022
# 4  Xie, Z., Nikolayeva, O., Luo, J., & Li, D. (20...  2019
#
#                                              Content
# 0  Diabetes prediction using machine learning and...
# 1  Prediction of diabetes disease using an ensemb...
# 2  An Ensemble Approach for the Prediction of Dia...
# 3  Performance analysis and prediction of type 2 ...
# 4  Building Risk Prediction Models for Type 2 Dia...

# %% [markdown]
# **2:Application of contractions**

# %%
# Expand contractions in the content column
df['Content_expanded'] = df['Content'].apply(lambda x: contractions.fix(x))
df.head()
# Out:
#                                            Citations  Year  \
# 0  Tasin, I., Nabil, T. U., Islam, S., & Khan, R....  2022
# 1  Abnoosian, K., Farnoosh, R., & Behzadi, M. H. ...  2023
# 2  Kibria, H. B., Nahiduzzaman, M., Goni, M. O. F...  2022
# 3  Ganie, S. M., Malik, M. B., & Arif, T. (2022)....  2022
# 4  Xie, Z., Nikolayeva, O., Luo, J., & Li, D. (20...  2019
#
#                                              Content  \
# 0  Diabetes prediction using machine learning and...
# 1  Prediction of diabetes disease using an ensemb...
# 2  An Ensemble Approach for the Prediction of Dia...
# 3  Performance analysis and prediction of type 2 ...
# 4  Building Risk Prediction Models for Type 2 Dia...
#
#                                     Content_expanded
# 0  Diabetes prediction using machine learning and...
# 1  Prediction of diabetes disease using an ensemb...
# 2  An Ensemble Approach for the Prediction of Dia...
# 3  Performance analysis and prediction of type 2 ...
# ...

# %% [markdown]
# **3: Removal of Special characters and numbers**

# %%
# Function to remove special characters and numbers
def remove_special_characters(text):
    return re.sub(r'[^A-Za-z\s]', '', text)
df['Content'] = df['Content_expanded'].str.lower()
df['Content'] = df['Content'].apply(remove_special_characters)
df.head()
# Out:
#                                            Citations  Year  \
# 0  Tasin, I., Nabil, T. U., Islam, S., & Khan, R....  2022
# 1  Abnoosian, K., Farnoosh, R., & Behzadi, M. H. ...  2023
# 2  Kibria, H. B., Nahiduzzaman, M., Goni, M. O. F...  2022
# 3  Ganie, S. M., Malik, M. B., & Arif, T. (2022)....  2022
# 4  Xie, Z., Nikolayeva, O., Luo, J., & Li, D. (20...  2019
#
#                                              Content  \
# 0  diabetes prediction using machine learning and...
# 1  prediction of diabetes disease using an ensemb...
# 2  an ensemble approach for the prediction of dia...
# 3  performance analysis and prediction of type  d...
# 4  building risk prediction models for type  diab...
#
#                                     Content_expanded
# 0  Diabetes prediction using machine learning and...
# 1  Prediction of diabetes disease using an ensemb...
# 2  An Ensemble Approach for the Prediction of Dia...
# 3  Performance analysis and prediction of type 2 ...
# ...

# %% [markdown]
# **4: Application of Tokenization**

# %%
# !pip install nltk
import nltk
from nltk.tokenize import word_tokenize

nltk.download('punkt')
# Out:
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
def tokenize_text(text):
   return word_tokenize(text)

# %%
df['tokens'] = df['Content'].apply(tokenize_text)
df.head()
# Out:
#                                            Citations  Year  \
# 0  Tasin, I., Nabil, T. U., Islam, S., & Khan, R....  2022
# 1  Abnoosian, K., Farnoosh, R., & Behzadi, M. H. ...  2023
# 2  Kibria, H. B., Nahiduzzaman, M., Goni, M. O. F...  2022
# 3  Ganie, S. M., Malik, M. B., & Arif, T. (2022)....  2022
# 4  Xie, Z., Nikolayeva, O., Luo, J., & Li, D. (20...  2019
#
#                                              Content  \
# 0  diabetes prediction using machine learning and...
# 1  prediction of diabetes disease using an ensemb...
# 2  an ensemble approach for the prediction of dia...
# 3  performance analysis and prediction of type  d...
# 4  building risk prediction models for type  diab...
#
#                                     Content_expanded  \
# 0  Diabetes prediction using machine learning and...
# 1  Prediction of diabetes disease using an ensemb...
# 2  An Ensemble Approach for the Prediction of Dia...
# 3  Performance analysis and prediction of type 2 ...
# ...

# %% [markdown]
# **5: Application of English stop words**

# %%
# Import the 'stopwords' corpus from the Natural Language Toolkit (NLTK)
from nltk.corpus import stopwords

# Download the set of stopwords from NLTK. This is necessary the first time you run this code.
nltk.download('stopwords')

# Define a function that removes stop words from a list of tokens.
# Stop words are common words that are usually filtered out in NLP tasks.
def remove_stop_words(tokens):
    # Create a set of English stop words. Sets are faster for membership tests than lists.
    stop_words_set = set(stopwords.words('english'))

    # Return a new list that contains only the tokens that are not stop words.
    # The token is also converted to lowercase to ensure case-insensitive matching.
    return [token for token in tokens if token.lower() not in stop_words_set]
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# Apply the 'remove_stop_words' function to the 'tokens' column of the dataframe 'df'.
# The result is a new column 'tokens_no_stop' in the dataframe 'df'.
df['tokens_no_stop'] = df['tokens'].apply(remove_stop_words)

# Display the first few rows of the DataFrame showing the 'content', 'tokens', and 'tokens_no_stop' columns.
# This gives a visual comparison between the original tokens and the tokens after stop words removal.
df[['Content', 'tokens', 'tokens_no_stop']].head()
# Out:
#                                              Content  \
# 0  diabetes prediction using machine learning and...
# 1  prediction of diabetes disease using an ensemb...
# 2  an ensemble approach for the prediction of dia...
# 3  performance analysis and prediction of type  d...
# 4  building risk prediction models for type  diab...
#
#                                               tokens  \
# 0  [diabetes, prediction, using, machine, learnin...
# 1  [prediction, of, diabetes, disease, using, an,...
# 2  [an, ensemble, approach, for, the, prediction,...
# 3  [performance, analysis, and, prediction, of, t...
# 4  [building, risk, prediction, models, for, type...
#
#                                       tokens_no_stop
# 0  [diabetes, prediction, using, machine, learnin...
# 1  [prediction, diabetes, disease, using, ensembl...
# 2  [ensemble, approach, prediction, diabetes, mel...
# 3  [performance, analysis, prediction, type, diab...
# 4  [building, risk, prediction, models, type, dia...

# %% [markdown]
# Installing word clouds

# %%
# !pip install wordcloud
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %% [markdown]
# **6: Application of Lemmitization**

# %%
#LEMMITIZATION
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

# Download necessary NLTK data
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')

# Function to map NLTK position tags to WordNet tags
def get_wordnet_pos(word, pos_tag):
    if pos_tag.startswith('J'):
        return wordnet.ADJ
    elif pos_tag.startswith('V'):
        return wordnet.VERB
    elif pos_tag.startswith('N'):
        return wordnet.NOUN
    elif pos_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
context_sensitive_stop_words = set([
    'year', 'level', 'diabetes', 'type 2 diabetes', 't2d', 'insulin', 'glucose', 'blood sugar', 'test', 'ml',
    'pancreas', 'metformin', 'hba1c', 'glycemic', 'hyperglycemia', 'hypoglycemia', 'td', 'dt',
    'insulin resistance', 'diabetic', 'mellitus', 'T2DM', 'endocrine', 'terms', 'often', 'help', 'tools', 'change', 'outperformed', 'diagnosed', 'undiagnosed', 'whether', 'aimed',
    'beta cells', 'diagnosis', 'complications', 'exercise', 'improvement', 'improve', 'within', 'applied', 'indetified', 'proposed', 'performed', 'measures', 'several', 'significant', 'significantly', 'conducted', 'shown', 'reduce', 'assess', 'consistent', 'validated',
    'prediabetes', 'antidiabetic', 'medication', 'blood', 'polyuria', 'select', 'selection', 'included', 'include', 'found', 'improved', 'observed','levels', 'available', 'subject', 'without', 'utilizd', 'achieved', 'prevalence', 'lead', 'measurements',
    'polydipsia', 'polyphagia', 'ADA', 'A1C', 'complication', 'retinopathy', 'algorithmatic', 'algorithms', 'tests', 'postive','although', 'applied','reported', 'collected', 'recommended', 'suggest', 'many', 'achieved', 'assessment', 'demonstrated', 'related',
    'neuropathy', 'nephropathy', 'amputation', 'level', 'well', 'including', 'large', 'inclusion', 'performance', 'negative', 'among', 'amongst', 'consider', 'consideration', 'findings', 'obtained', 'limitations', 'current', 'less', 'relative', 'might', 'shows', 'various', 'indicate',
    'hypertension', 'lipid profile', 'microvascular', 'macrovascular', 'SGLT2 inhibitor', 'pressure', 'use', 'useful', 'uses', 'developing', 'general', 'intervention', 'potential', 'application', 'better', 'suggests', 'considered', 'consistently', 'evaluated', 'followed', 'indicates',
    'DPP-4 inhibitor', 'GLP-1 receptor agonist', 'hypoglycemic', 'DKA', 'ketosis','hbac', 'increased', 'decreased', 'disease', 'evaluation', 'predict', 'prediction', 'associations', 'associating', 'p', 'comparings', 'find', 'indicator', 'term', 'subjects',
    'hyperosmolar hyperglycemic state', 'diabetes management', 'blood', 'medical', 'health', 'gdm', 'analysis', 'analyses', 'development', 'compare', 'compariosn', 'comparing', 'differeny', 'apply', 'reporting', 'reports', 'develop', 'additional', 'detection', 'estimate',
    'insulin', 'continuous' , 'monitoring', 'modification', 'type', 'risk', 'risk', 'chronic', 'outcome', 'predictors', 'predictor', 'may', 'testing', 'train', 'system', 'equation', 'accurate', 'future', 'nonivasive', 'cluster', 'associate', 'defined',
    'risk', 'genetic', 'pancreatic beta cells', 'ADA', 'score', 'cohort', 'showed', 'clinical', 'clinic', 'studies', 'developments', 'association', 'entropy', 'knn', 'datasets', 'framework', 'frameowrks', 'case', 'cases', 'limitation', 'excluded', 'established',
    'diabetic retinopathy', 'diabetic nephropathy', 'diabetic neuropathy', 'tunning', 'predict', 'error', 'sampling', 'table', 'tables', 'svm', 'laboratory', 'identify', 'people', 'lab', 'compares', 'measure', 'measurement', 'compared', 'selected', 'identified',
    'diabetic foot', 'diabetic', 'medical nutrition therapy', 'machine-learning', 'ML', 'supervised', 'unsupervised', 'classification', 'classifier', 'machinelearning', 'using', 'populations', 'demonstrate', 'demonstration', 'lr', 'noninvasive', 'additionally',
    'regression', 'predictive', 'selection', 'engineering', 'model', 'dataset', 'file', 'files', 'records', 'record', 'individual', 'individuals', 'summary', 'new', 'column','columns', 'row', 'rows', 'missing', 'imputing', 'imputation', 'due', 'database', 'respectively',
    'model evaluation', 'crossvalidation', 'overfitting', 'underfitting', 'ensemble', 'crossvalidation', 'modeling', 'population', 'predicting', 'prediction', 'high', 'low', 'increase', 'decrease', 'percentage', 'points', 'point', 'random', 'forest', 'forests',
    'network', 'support', 'vector', 'SVM', 'logistic', 'decision', 'tree', 'trees', 'search', 'neighbors', 'algortihim', 'based', 'important', 'introduction', 'importance', 'percentages', 'develops', 'sick', 'include', 'curves', 'wellness' 'shows', 'finally',
    'neural', 'deep', 'XGBoost', 'SMOTE', 'upsampling', 'downsampling', 'conlcusion', 'performance', 'diseases', 'diseases', 'feature', 'features', 'variable', 'variables', 'factor', 'factors', 'years', 'roc', 'characteristics', 'sample', 'strong', 'weak',
    'area under the curve', 'AUC', 'precision', 'recall', 'F1 score', 'accuracy', 'confusion matrix', 'hyperparameter', 'code', 'coding', 'discussion', 'discussions', 'increases', 'decreases', 'alogrithm', 'alogrithms', 'accuracy', 'clusters', 'clustering',
    'tuning', 'grid', 'gradient', 'boosting', 'XGB' 'k-nearest', 'KNN', 'ensemble', 'tradeoff', 'rate', 'curve', 'figure', 'figures', 'graph', 'result', 'results', 'conclusion', 'et', 'al' , 'science', 'python', 'class', 'label', 'labels', 'furthermore', 'mean',
    'imbalanced', 'ROC', 'learning', 'cross-entropy', 'ai', 'techniques', 'set', 'sets', 'method', 'methods', 'result', 'feature', 'features', 'auc', 'algorithm', 'approach', 'xgboost', 'screening', 'number', 'statistics', 'classifiers', 'second', 'first',
    'scaling', 'deployment', 'interpretation', 'biasvariance','bias-variance', 'bias', 'variance', 'hyperparametre', 'used', 'findings', 'discussion', 'performance', 'standardization', 'normalization', 'outliers', 'extreme', 'value', 'values', 'developed',
    'validations', 'test', 'training', 'preprocessing', 'hyperparameter optimization', 'machine', 'learning', 'models', 'hyperparameter', 'variable', 'data', 'study', 'patient', 'patients', 'research', 'tdm', 'model', 'result', 'variables', 'associated',
    'lower', 'lowest', 'algorithm', 'comparisons', 'high', 'different', 'highest', 'apply', 'identify', 'higher', 'obtain', 'provide', 'evalaution', 'present', 'achieve', 'measure', 'report', 'information', 'similar', 'perform', 'family', 'history', 'propose',
    'tool', 'need', 'evluation', 'weight', 'evalautes', 'previous', 'one', 'two', 'three', 'four', 'five', 'six', 'early', 'ability', 'validate', 'cross', 'validation', 'characteristic', 'rf', 'best', 'show', 'indication', 'inidcate', 'build', 'cutoff'
])

# %% [markdown]
# **7: Application of context sensitive words**

# %%
# English stop words
stop_words_set = set(stopwords.words('english'))

# Extend the previously defined function to remove both general and context-sensitive stop words
def remove_context_sensitive_stop_words(tokens):
    # Combine the general English stop words with the context-specific stop words
    # to create a comprehensive set of words to filter out.
    all_stop_words = stop_words_set | context_sensitive_stop_words
    return [token for token in tokens if token.lower() not in all_stop_words]

# Apply the updated function to remove both general and context-sensitive stop words
df['tokens_no_stop_context'] = df['tokens'].apply(remove_context_sensitive_stop_words)

# Display the DataFrame
df[['Content', 'tokens', 'tokens_no_stop_context']].head()
# Out:
#                                              Content  \
# 0  diabetes prediction using machine learning and...
# 1  prediction of diabetes disease using an ensemb...
# 2  an ensemble approach for the prediction of dia...
# 3  performance analysis and prediction of type  d...
# 4  building risk prediction models for type  diab...
#
#                                               tokens  \
# 0  [diabetes, prediction, using, machine, learnin...
# 1  [prediction, of, diabetes, disease, using, an,...
# 2  [an, ensemble, approach, for, the, prediction,...
# 3  [performance, analysis, and, prediction, of, t...
# 4  [building, risk, prediction, models, for, type...
#
#                               tokens_no_stop_context
# 0  [explainable, globally, affects, million, maki...
# 1  [multiclassifier, background, objective, lifet...
# 2  [soft, voting, explainable, continues, primary...
# 3  [lifestyle, approaches, objective, fatal, affe...
# 4  [building, prevalent, united, states, especial...

# %%
# Function to lemmatize a list of tokens with POS tags
def lemmatize_tokens_with_pos(tokens):
    tagged_tokens = nltk.pos_tag(tokens)
    return [lemmatizer.lemmatize(word, get_wordnet_pos(word, tag)) for word, tag in tagged_tokens]

# Apply this function to the 'tokens' column
df['lemmatized'] = df['tokens_no_stop_context'].apply(lemmatize_tokens_with_pos)

# %%
# Display the DataFrame
df[['tokens_no_stop_context', 'lemmatized']].head()
# Out:
#                               tokens_no_stop_context  \
# 0  [explainable, globally, affects, million, maki...
# 1  [multiclassifier, background, objective, lifet...
# 2  [soft, voting, explainable, continues, primary...
# 3  [lifestyle, approaches, objective, fatal, affe...
# 4  [building, prevalent, united, states, especial...
#
#                                           lemmatized
# 0  [explainable, globally, affect, million, make,...
# 1  [multiclassifier, background, objective, lifet...
# 2  [soft, voting, explainable, continue, primary,...
# 3  [lifestyle, approach, objective, fatal, affect...
# 4  [building, prevalent, united, state, especiall...

# %%
# Combine all tokens from the 'lemmatized' column into a single list
all_tokens = sum(df['lemmatized'].tolist(), [])

# Create a text string required by WordCloud
text = ' '.join(all_tokens)

# Create a WordCloud object
wordcloud = WordCloud(width = 800, height = 800,
                      background_color ='white',
                      colormap='magma',  # Use the 'magma' colormap
                      min_font_size = 9).generate(text)

# Plot the WordCloud image
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

# %%
# Accessinh the words and their frequencies from the WordCloud object
word_freq = wordcloud.words_

# Converting the dictionary to a list of tuples (word, frequency)
word_freq_list = [(word, freq) for word, freq in word_freq.items()]

# Sorting the list by frequency in descending order
sorted_word_freq_list = sorted(word_freq_list, key=lambda x: x[1], reverse=True)

# Displaying the sorted list of words and their frequencies
for word, freq in sorted_word_freq_list:
    print(f"{word}: {freq}")
# Out:
# age: 1.0
# bmi: 0.5566037735849056
# work: 0.49056603773584906
# group: 0.41509433962264153
# survey: 0.39622641509433965
# status: 0.3867924528301887
# incidence: 0.3867924528301887
# area: 0.36792452830188677
# time: 0.3490566037735849
# prevention: 0.3490566037735849
# woman: 0.3490566037735849
# size: 0.330188679245283
# progression: 0.330188679245283
# onset: 0.330188679245283
# addition: 0.32075471698113206
# intervention: 0.32075471698113206
# cardiovascular: 0.3113207547169811
# simple: 0.3018867924528302
# sensitivity specificity: 0.3018867924528302
# lifestyle: 0.29245283018867924
# obesity: 0.29245283018867924
# care: 0.2830188679245283
# key: 0.2830188679245283
# require: 0.2830188679245283
# participant: 0.2830188679245283
# sensitivity: 0.2830188679245283
# baseline: 0.2830188679245283
# give: 0.27358490566037735
# healthcare: 0.27358490566037735
# effect: 0.27358490566037735
# country: 0.27358490566037735
# likely: 0.27358490566037735
# parameter: 0.2641509433962264
# ...
